# %% [markdown]
# ## Loading the dataset

# %%
import pandas as pd
import numpy as np

# %%
## Loading the dataset
data = pd.read_csv("D:/Web Scraping using Python/productsfull.csv")

# %%
data.head(5)
# Out:
#                                      fulldescription  \
# 0  ["The world's #1-selling hunting knife in its ...
# 1  ["We've combined the freedom of a sandal with ...
# 2  ["This is the ultimate sportsman's day pack. D...
# 3  ['These fur-ocious kids’ animal slippers will ...
# 4  ['Our Baby Bogs set the standard in toddlers’ ...
#
#                                productname            fit  \
# 0          Buck 110 Folding Hunter's Knife  Not Available
# 1                   Kids' Explorer Sandals  Not Available
# 2            Maine Warden's Day Pack, Camo  Not Available
# 3           Toddlers' Animal Paws Slippers  Not Available
# 4  Toddlers' Baby Bogs Boots, Classic Dino  Not Available
#
#                                            colorname
# 0                                      Not Available
# 1  ['Bright Sapphire', 'Cactus', 'Night', 'Teal S...
# 2                              ['Mossy Oak Country']
# 3                                            ['Owl']
# ...
