# %% [markdown]
# ## Loading the dataset

# %%
import pandas as pd
import numpy as np

# %%
## Loading the dataset
data = pd.read_csv("D:/Web Scraping using Python/productsfull.csv")

# %%
data.head(5)
# Out:
#                                      fulldescription  \
# 0  ["The world's #1-selling hunting knife in its ...
# 1  ["We've combined the freedom of a sandal with ...
# 2  ["This is the ultimate sportsman's day pack. D...
# 3  ['These fur-ocious kids’ animal slippers will ...
# 4  ['Our Baby Bogs set the standard in toddlers’ ...
#
#                                productname            fit  \
# 0          Buck 110 Folding Hunter's Knife  Not Available
# 1                   Kids' Explorer Sandals  Not Available
# 2            Maine Warden's Day Pack, Camo  Not Available
# 3           Toddlers' Animal Paws Slippers  Not Available
# 4  Toddlers' Baby Bogs Boots, Classic Dino  Not Available
#
#                                            colorname
# 0                                      Not Available
# 1  ['Bright Sapphire', 'Cactus', 'Night', 'Teal S...
# 2                              ['Mossy Oak Country']
# 3                                            ['Owl']
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24731 entries, 0 to 24730
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fulldescription  24731 non-null  object
#  1   productname      24714 non-null  object
#  2   fit              24731 non-null  object
#  3   colorname        24731 non-null  object
# dtypes: object(4)
# memory usage: 773.0+ KB

# %%
### Cleaning
## Null Values
data.isnull().sum()
# Out:
# fulldescription     0
# productname        17
# fit                 0
# colorname           0
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# fulldescription    0
# productname        0
# fit                0
# colorname          0
# dtype: int64

# %%
## Duplicates
print(data.duplicated().sum())
# Out:
# 19592

# %%
data.drop_duplicates(keep = 'last', inplace = True)

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5122 entries, 307 to 24730
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fulldescription  5122 non-null   object
#  1   productname      5122 non-null   object
#  2   fit              5122 non-null   object
#  3   colorname        5122 non-null   object
# dtypes: object(4)
# memory usage: 200.1+ KB

# %%
data
# Out:
#                                          fulldescription  \
# 307    ['The Black Hole archery target is easy to set...
# 792    ['This compact home safe is perfect for the pe...
# 881    ['This super-tough, compact safe fits into mos...
# 892    ["Protect your handguns and rifles from moistu...
# 988    ['This portable lock box is ideal for securing...
# ...                                                  ...
# 24726  ["We made this lightweight everyday blanket fr...
# 24727  ['Beautiful flowers bloom across the inside of...
# 24728  ['Our amazingly plush blanket teams up with th...
# 24729  ['Crafted from cotton twill for a beautiful dr...
# 24730  ['This L.L.Bean exclusive Maine blanket is cra...
#
#                                          productname            fit  \
# 307                        Black Hole Archery Target  Not Available
# 792    Stack-On Quick Access Safe With Electric Lock  Not Available
# 881               Stack-On Electric Lock Drawer Safe  Not Available
# ...
